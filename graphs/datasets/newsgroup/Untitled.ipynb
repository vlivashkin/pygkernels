# %%
import numpy as np

# %%
from numpy import genfromtxt
my_data = genfromtxt('news_2cl_1_Docr.csv', delimiter=',')

# %%
print 'INSERT INTO logistic_edges (`from`, `to`, weight) VALUES '
for i in range(0, 400):
    for j in range(0, 400):
        if my_data[i, j] > 0:
            print '(' + str(i) + ', ' + str(j) + ", " + str(my_data[i, j] *100) +"),"
# Out:
# INSERT INTO logistic_edges (`from`, `to`, weight) VALUES
# (0, 2, 11.475),
# (0, 5, 3.2168),
# (0, 7, 4.783),
# (0, 8, 11.399),
# (0, 14, 1.4777),
# (0, 15, 1.0705),
# (0, 16, 6.9107),
# (0, 17, 0.79329),
# (0, 18, 2.1491),
# (0, 27, 3.2546),
# (0, 29, 0.43826),
# (0, 31, 0.91053),
# (0, 32, 0.66268),
# (0, 34, 3.4015),
# (0, 35, 0.53921),
# (0, 36, 0.55972),
# (0, 37, 0.62678),
# (0, 40, 0.71303),
# (0, 41, 0.75785),
# (0, 42, 1.6336),
# (0, 46, 1.384),
# (0, 47, 2.4902),
# (0, 48, 0.77578),
# (0, 55, 4.4998),
# (0, 56, 2.772),
# (0, 57, 0.41351),
# (0, 58, 0.86232),
# (0, 60, 1.8881),
# (0, 61, 2.9298),
# (0, 62, 4.6437),
# (0, 63, 1.0102),
# (0, 67, 0.38802),
# (0, 68, 0.84639),
# (0, 70, 1.5811),
# (0, 71, 18.5),
# (0, 72, 1.0122),
# (0, 76, 0.49114),
# (0, 78, 3.9989),
# (0, 79, 0.97249),
# (0, 81, 0.51926),
# (0, 83, 3.8228),
# (0, 84, 5.4173),
# (0, 86, 0.57824),
# (0, 88, 0.46209),
# (0, 90, 3.5229),
# (0, 91, 2.1798),
# (0, 93, 0.44738),
# (0, 96, 1.8766),
# ...
